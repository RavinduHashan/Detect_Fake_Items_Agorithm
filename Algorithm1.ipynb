# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import re
import nltk

List1 = []

psg = pd.read_csv('PSG2.csv')
psg['ip_type'] = psg['ip_type'].fillna(0)
psg.ip_type[psg.ip_type == 'counterfeit'] = 1
psg

for i in psg['market_place']:
  X1 = re.sub('[^a-zA-Z]', ' ', i )
  X1 = ''.join(X1)
  List1.append(X1)
List1 

cv = CountVectorizer()
X1 = cv.fit_transform(List1).toarray()
y = psg.iloc[:, 14].values
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size = 0.20, random_state = 0)
classifier = SVC()
classifier.fit(X_train, y_train)

# psg.fillna(0)
#X = psg.drop(columns=['id','Seller_link','Seller_name','Product_id','date_detected','Listing_status','page_link','Item_image','ip_type',	'text_search'], axis=1, inplace=False)
#y = psg.drop(columns=['id','Seller_link','Seller_name','Product_id','market_place','search_terms','Quantity','date_detected','price','Listing_status','Title','page_link','Item_image','text_search','ocr_search','logo_detection','price_val'], axis=1, inplace=False)
#y = psg['ip_type']
#y['ip_type'].value_counts()
#y['ip_type'].isna().sum()
# X1 = psg[['market_place']]
# X2 = psg[['search_terms']]
# X3 = psg[['Quantity']]
# X4 = psg[['price']]
# X5 = psg[['Title']]
# X6 = psg[['ocr_search']]
# X7 = psg[['logo_detection']]
# psg.ip_type[psg.ip_type == 'counterfeit'] = 1
# psg.ip_type[psg.ip_type == 'NaN'] = 0
# y = psg['ip_type']

# X1 = list[psg[['market_place']]]
# X1

#Find NaN value
#psg.isna()
#psg.info()
# cv = CountVectorizer()
# X1 = cv.fit_transform(X1).toarray()
# X1
# y

# classifier = SVC(kernel = 'rbf', gamma= 'scale' , C=1 , random_state = 1)
# classifier.fit(X1, y)

# model = DecisionTreeClassifier()
# model.fit(X7, y)

# %%
# cv = CountVectorizer()
# X1 = cv.fit_transform(X1).toarray()
# y = cv.fit_transform(y).toarray()

# %%
model = DecisionTreeClassifier()
model.fit(X7, y)
# X_train, X_test, y_train, y_test = train_test_split(X7, y, train_size = 0.8)
# model = DecisionTreeClassifier()
# model.fit(X_train, y_train)
# predictions = model.predict(X_test)
# predictions
